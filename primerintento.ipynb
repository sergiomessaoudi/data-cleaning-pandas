# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sharks = pd.read_csv("data/attacks.csv",encoding = "ISO-8859-1")

# %%
sharks.sample(6)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 20264         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 16487         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 10554         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 16207         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 10660         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 20704         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 20264  ...      NaN                    NaN  NaN          NaN  NaN
# 16487  ...      NaN                    NaN  NaN          NaN  NaN
# 10554  ...      NaN                    NaN  NaN          NaN  NaN
# 16207  ...      NaN                    NaN  NaN          NaN  NaN
# 10660  ...      NaN                    NaN  NaN          NaN  NaN
# ...

# %%
sharks.shape
# Out:
# (25723, 24)

# %%
sharks.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
sharks.dropna(how="all", inplace=True)

# %%
sharks.shape
# Out:
# (8703, 24)

# %%
#sharks.fillna(sharks.mean(), inplace=True)

# %%
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
sharks.drop(["Name", "pdf","href formula","href","Case Number.1","Case Number.2","Unnamed: 22","Unnamed: 23"],axis=1,inplace=True)

# %%
sharks.shape
# Out:
# (8703, 16)

# %%
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity Sex   Age  \
# 0     Oceanside, San Diego County     Paddling    F   57
# 1  St. Simon Island, Glynn County     Standing    F   11
# 2                    Habush, Oahu      Surfing    M   48
# 3              Arrawarra Headland      Surfing    M  NaN
# 4                        La Ticla  Free diving    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# ...

# %%
sharks.drop(["Case Number","original order","Investigator or Source"],axis=1,inplace=True)

# %%
sharks.shape
# Out:
# (8703, 13)

# %%
sharks.Type.unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
sharks.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity Sex   Age  \
# 0     Oceanside, San Diego County     Paddling    F   57
# 1  St. Simon Island, Glynn County     Standing    F   11
# 2                    Habush, Oahu      Surfing    M   48
# 3              Arrawarra Headland      Surfing    M  NaN
# 4                        La Ticla  Free diving    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# ...

# %%
sharks.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species '],
#       dtype='object')

# %%
sharks.shape
# Out:
# (8703, 13)

# %%
sharks["Sex "].describe()
# Out:
# count     5737
# unique       6
# top          M
# freq      5094
# Name: Sex , dtype: object

# %%
sharks.Injury.unique()
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
sharks.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species '],
#       dtype='object')

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 25722
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         6302 non-null   object
#  1   Year         6300 non-null   float64
#  2   Type         6298 non-null   object
#  3   Country      6252 non-null   object
#  4   Area         5847 non-null   object
#  5   Location     5762 non-null   object
#  6   Activity     5758 non-null   object
#  7   Sex          5737 non-null   object
#  8   Age          3471 non-null   object
#  9   Injury       6274 non-null   object
#  10  Fatal (Y/N)  5763 non-null   object
#  11  Time         2948 non-null   object
#  12  Species      3464 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 951.9+ KB

# %%
display(sharks)
# Out:
#               Date    Year        Type    Country             Area  \
# 0      25-Jun-2018  2018.0     Boating        USA       California
# 1      18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2      09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3      08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4      04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...            ...     ...         ...        ...              ...
# 8698           NaN     NaN         NaN        NaN              NaN
# 8699           NaN     NaN         NaN        NaN              NaN
# 8700           NaN     NaN         NaN        NaN              NaN
# 8701           NaN     NaN         NaN        NaN              NaN
# 25722          NaN     NaN         NaN        NaN              NaN
#
#                              Location     Activity Sex   Age  \
# 0         Oceanside, San Diego County     Paddling    F   57
# ...

# %%
sharks.Country.value_counts()
# Out:
# USA                 2229
# AUSTRALIA           1338
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     134
# NEW ZEALAND          128
#                     ...
#  PHILIPPINES           1
# COOK ISLANDS           1
# Coast of AFRICA        1
# ANDAMAN ISLANDS        1
# SLOVENIA               1
# Name: Country, Length: 212, dtype: int64

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 25722
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         6302 non-null   object
#  1   Year         6300 non-null   float64
#  2   Type         6298 non-null   object
#  3   Country      6252 non-null   object
#  4   Area         5847 non-null   object
#  5   Location     5762 non-null   object
#  6   Activity     5758 non-null   object
#  7   Sex          5737 non-null   object
#  8   Age          3471 non-null   object
#  9   Injury       6274 non-null   object
#  10  Fatal (Y/N)  5763 non-null   object
#  11  Time         2948 non-null   object
#  12  Species      3464 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 951.9+ KB

# %%
#Hipotesis 1 : Los ataques de tiburón se dan más durante los meses de verano que en el resto del año.
#Hipótesis 2: Estados Unidos es el país con mayor cantidad de ataques registrados en todo el mundo.
#Hipótesis 3: En cuanto al sexo, los hombres son más propensos a los ataques de tiburón que las mujeres debido a los mayores riesgos que asumen

# %% [markdown]
#     Limpieza columna Date

# %%
sharks["Date"] = pd.to_datetime(sharks["Date"], errors="coerce")

# %%
sharks["Date"].unique
# Out:
# <bound method Series.unique of 0       2018-06-25
# 1       2018-06-18
# 2       2018-06-09
# 3       2018-06-08
# 4       2018-06-04
#            ...
# 8698           NaT
# 8699           NaT
# 8700           NaT
# 8701           NaT
# 25722          NaT
# Name: Date, Length: 8703, dtype: datetime64[ns]>

# %%
print("Day:",sharks['Date'][0].day)
print("Month:",sharks['Date'][0].month)
print("Year:",sharks['Date'][0].year)
print("Weekday:",sharks['Date'][0].isoweekday())
# Out:
# Day: 25
# Month: 6
# Year: 2018
# Weekday: 1

# %%
sharks["Month"] = pd.DatetimeIndex(sharks['Date']).month_name()
sharks
# Out:
#             Date    Year        Type    Country             Area  \
# 0     2018-06-25  2018.0     Boating        USA       California
# 1     2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2     2018-06-09  2018.0     Invalid        USA           Hawaii
# 3     2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018-06-04  2018.0    Provoked     MEXICO           Colima
# ...          ...     ...         ...        ...              ...
# 8698         NaT     NaN         NaN        NaN              NaN
# 8699         NaT     NaN         NaN        NaN              NaN
# 8700         NaT     NaN         NaN        NaN              NaN
# 8701         NaT     NaN         NaN        NaN              NaN
# 25722        NaT     NaN         NaN        NaN              NaN
#
#                              Location     Activity Sex   Age  \
# 0         Oceanside, San Diego County     Paddling    F   57
# ...

# %%
sharks.head()
# Out:
#         Date    Year        Type    Country             Area  \
# 0 2018-06-25  2018.0     Boating        USA       California
# 1 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4 2018-06-04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity Sex   Age  \
# 0     Oceanside, San Diego County     Paddling    F   57
# 1  St. Simon Island, Glynn County     Standing    F   11
# 2                    Habush, Oahu      Surfing    M   48
# 3              Arrawarra Headland      Surfing    M  NaN
# 4                        La Ticla  Free diving    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# ...

# %%
sharks = sharks.dropna()

# %%
sharks.shape
# Out:
# (1410, 14)

# %%
sharks.Date.isna()
# Out:
# 0       False
# 6       False
# 8       False
# 10      False
# 13      False
#         ...
# 5545    False
# 5648    False
# 5684    False
# 5814    False
# 5922    False
# Name: Date, Length: 1410, dtype: bool

# %%
sharks.reset_index()
# Out:
#       index       Date    Year        Type       Country  \
# 0         0 2018-06-25  2018.0     Boating           USA
# 1         6 2018-06-03  2018.0  Unprovoked        BRAZIL
# 2         8 2018-05-26  2018.0  Unprovoked           USA
# 3        10 2018-05-24  2018.0    Provoked     AUSTRALIA
# 4        13 2018-05-13  2018.0     Invalid       ENGLAND
# ...     ...        ...     ...         ...           ...
# 1405   5545 1901-07-30  1901.0  Unprovoked  SOUTH AFRICA
# 1406   5648 1894-11-28  1894.0  Unprovoked     AUSTRALIA
# 1407   5684 1892-03-02  1892.0    Provoked     AUSTRALIA
# 1408   5814 1880-11-25  1880.0  Unprovoked     AUSTRALIA
# 1409   5922 1868-05-13  1868.0  Unprovoked         INDIA
#
#                        Area                      Location        Activity  \
# 0                California   Oceanside, San Diego County        Paddling
# 1                Pernambuco         Piedade Beach, Recife        Swimming
# ...

# %%
sharks["Type"].value_counts()
# Out:
# Unprovoked      1280
# Provoked         103
# boat              17
# Invalid            5
# Sea Disaster       5
# Name: Type, dtype: int64

# %%
def barquito(abc):
    if (abc.lower()).startswith("boat"):
        return "boat"
    else:
        return abc

# %%
sharks["Type"] = sharks["Type"].apply(barquito)
# Out:
# <ipython-input-44-87ed828fe5b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks["Type"] = sharks["Type"].apply(barquito)

# %%
sharks.Type
# Out:
# 0             boat
# 6       Unprovoked
# 8       Unprovoked
# 10        Provoked
# 13         Invalid
#            ...
# 5545    Unprovoked
# 5648    Unprovoked
# 5684      Provoked
# 5814    Unprovoked
# 5922    Unprovoked
# Name: Type, Length: 1410, dtype: object
